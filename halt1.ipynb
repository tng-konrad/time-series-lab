# %% [markdown]
# # Setup

# %%
# Standard library imports
import math
import random
from dataclasses import dataclass
from typing import List, Tuple

# Third-party imports
import numpy as np
from sklearn.metrics import f1_score, roc_auc_score
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from sklearn.preprocessing import minmax_scale

# # PyTorch imports
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset, random_split
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence, pad_sequence

from visualise import (plot_feature_importance, compute_feature_importance,
                plot_feature_correlation, plot_sensitivity_analysis)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 21
#      18 from torch.utils.data import DataLoader, Dataset, random_split
#      19 from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence, pad_sequence
# ---> 21 from visualise import (plot_feature_importance, compute_feature_importance,
#      22                 plot_feature_correlation, plot_sensitivity_analysis)
#
# File ~/Documents/time-series-lab/visualise.py:9
#       6 from sklearn.manifold import TSNE
#       7 from sklearn.preprocessing import minmax_scale
# ----> 9 from visualize import plot_feature_importance, compute_feature_importance
#      10 from visualize import plot_feature_correlation
#      11 from visualize import plot_t_sne_embeddings
#
# ModuleNotFoundError: No module named 'visualize'

# %% [markdown]
# TODO

# %%
# general settings
class CFG:
    img_dim1 = 20
    img_dim2 = 10
    SEED = 42

# display style 
plt.style.use("seaborn-v0_8")
plt.rcParams["figure.figsize"] = (CFG.img_dim1, CFG.img_dim2)

# Setup
device = torch.device(CFG.device)
print(f"Using device: {device}")
print(f"PyTorch Version: {torch.__version__}")

# fix randomness (insofar as possible ;-)
SEED = 42
random.seed(CFG.SEED)
np.random.seed(CFG.SEED)
torch.manual_seed(CFG.SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(CFG.SEED)

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
